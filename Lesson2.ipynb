# %%
import tensorflow as tf

x = tf.constant(35, name='x')
y = tf.Variable(x + 5, name='y')

print(y)

# %%
x = tf.constant(35, name='x')
y = tf.Variable(x + 5, name='y')

model = tf.initialize_all_variables()

with tf.Session() as session:
    session.run(model)
    print(session.run(y))
# Out:
# 40

# %% [markdown]
# # Excercises

# %% [markdown]
# ### 1) Constants can also be arrays. Predict what this code will do, then run it to confirm:

# %%
x = tf.constant([35, 40, 45], name='x')
y = tf.Variable(x + 5, name='y')


model = tf.initialize_all_variables()

with tf.Session() as session:
	session.run(model)
	print(session.run(y))
# Out:
# [40 45 50]

# %% [markdown]
# ### 2) Generate a NumPy array of 10,000 random numbers (called x) and create a Variable storing the equation
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>y</mi>
#   <mo>=</mo>
#   <mn>5</mn>
#   <msup>
#     <mi>x</mi>
#     <mn>2</mn>
#   </msup>
#   <mo>&#x2212;<!-- − --></mo>
#   <mn>3</mn>
#   <mi>x</mi>
#   <mo>+</mo>
#   <mn>15</mn>
# </math>

# %%
import numpy as np

# %%
data = np.random.randint(1000, size=1000)

# %%
x = tf.constant(data, name='x')
y = tf.Variable(5 * x**2 - 3*x + 15, name='y')


model = tf.initialize_all_variables()

with tf.Session() as session:
	session.run(model)
	print(session.run(y))
# Out:
# [2162861 2855427    1095  618479 1340081 3491987 3133959 4701605 4321725
#  2969907 4779501 1499891  261533  868209      51     953 2189249   45807
#   287295  573603 1786241 3000815 3878177 1165011    1763 2468951 3335009
#  2511293 2589855   35885 4340339 3367757  763247   32577 2728403  382829
#    29429 1605759 2262641   63521  329489  268439   70463 2640479 1098413
#  1024701 1467209   60185 3433733    2369 1982625 1510865   79017 2855427
#   962303 2582663 2985341  806829 3408917 3047477 3984581  280149 2946831
#  1258529  827039 3118145  113567 4653245 1451003 3126047   22259 2758031
#    81551  152615 2518385    1095 1253517  132371 4779501   58011 3652575
#   763247  319301  135645 3483635  614967 1895447  301857  213639 1006673
#   221987   75291 1840439   93449 2420007   19049  492053 3450327 4074351
#   311765   10005  250223  301857  380067 4740473  385601  236981   47741
#  1184399 3351363  326927  138959 2669627 2490077 3584519  971097 2618723
# ...

# %% [markdown]
# ### 3) You can also update variables in loops, which we will use later for machine learning. Take a look at this code, and predict what it will do (then run it to check):

# %%
x = tf.Variable(0, name='x')

model = tf.initialize_all_variables()

with tf.Session() as session:
    for i in range(5):
        session.run(model)
        x = x + 1
        print(session.run(x))
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### 4) Using the code from (2) and (3) above, create a program that computers the “rolling” average of the following line of code: np.random.randint(1000). In other words, keep looping, and in each loop, call np.random.randint(1000) once in that loop, and store the current average in a Variable that keeps updating each loop.

# %%
x = tf.Variable(0, name='x')

model = tf.initialize_all_variables()

with tf.Session() as session:
    for i in range(5):
        session.run(model)
        avg = np.average(np.random.randint(1000, size=1000))
        print("this is avg %s" % str(avg))
        x = x + avg
        print(session.run(x))
# Out:
# this is avg 491.817
# 491
# this is avg 496.27
# 987
# this is avg 513.873
# 1500
# this is avg 488.89
# 1988
# this is avg 508.625
# 2496

# %% [markdown]
# ### 5) Use TensorBoard to visualise the graph for some of these examples. Note that as of writing (December 2015), this will not work in Python 3 but is due to be fixed in the next release. Come back and try again soon!

# %%
x = tf.constant(35, name='x')
print(x)
y = tf.Variable(x + 5, name='y')

with tf.Session() as session:
    merged = tf.merge_all_summaries()
    writer = tf.train.SummaryWriter("basic", session.graph)
    model = tf.initialize_all_variables()
    session.run(model)
    print(session.run(y))
# Out:
# Tensor("x_28:0", shape=(), dtype=int32)
# 40
